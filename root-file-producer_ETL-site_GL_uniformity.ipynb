# %%
# This block to be used for 16x16 Vgl unfirmtiy during the pre-series

import os
import ROOT as root
import numpy as np
from array import array
import glob
import re

wafer = 12
sensor_column=5
sensor_row=5

file = root.TFile("/Users/icosivi/Desktop/LC2_W"+str(wafer)+"_"+str(sensor_column)+"-"+str(sensor_row)+"_16x16_GL-uniformity_ETL-site.root", "RECREATE")
tree = root.TTree("Tree","Tree")

event = array('i', [0])
pad_row = array('i', [0])
pad_column = array('i', [0])

V = root.std.vector("float")()
CP = root.std.vector("float")()

tree.Branch("event", event, 'event/I')
tree.Branch("pad_row", pad_row, 'pad_row/I')
tree.Branch("pad_column", pad_column, 'pad_column/I')


V.reserve(1000)
CP.reserve(1000)
tree.Branch("V", "std::vector<float>", V)
tree.Branch("CPAD", "std::vector<float>", CP)

txt_files = []

txt_files.append(glob.glob("/Users/icosivi/Desktop/W12_GL_Uniformity/"+str(sensor_column)+"-"+str(sensor_row)+"/*.txt"))

start_line = 135  #Depending on the device analyzer, values may start from line xxx (PSSA) or 135 (PSF), choose the value accordingly. And do not mix files from different device analyzers!

counter = 0

for t in txt_files:
  for txt in t:
    #print(txt)

    V.clear()
    CP.clear()

    event[0] = counter

    with open(txt,"r") as t:
        lines_list = t.readlines()
        lineo = lines_list[0]
        header_line = re.split(" |\t",lineo)
        header = re.split('_|-|\n',header_line[2])
        print(header)
        pad_column[0] = int( header[7] )
        pad_row[0] = int( header[8] )
        
        linetwo = lines_list[2]
        date_line = re.split(" |\t|\n",linetwo)
        #print(date_line)
        date = str(date_line[2])
        
        lines = lines_list[start_line:]

        '''
        for line in lines:
            if float(line.split("	")[1])<0:
                IBACK.push_back( -1*float(line.split("	")[1]) )
            else:
                IBACK.push_back( float(line.split(" ")[1]) )

            if(V.size()>3):
                if( -1*float(line.split("	")[0])>V.at( V.size()-1 ) ):
                    V.push_back( -1*float(line.split("	")[0]) )
                else:
                    break
            else:
                V.push_back( -1*float(line.split("	")[0]) )

        '''
        for k,line in enumerate(lines):
            if float(line.split("	")[0])<0:
                if( V.size()>3):
                    if( -1*float(line.split("	")[0])>-1*float(lines[k-1].split("	")[0]) ):
                    #if( -1*float(line.split("	")[0])>V.at( V.size()-1 ) ):
                        V.push_back( -1*float(line.split("	")[0]) )
                    else:
                        break
                else:
                    V.push_back( -1*float(line.split("	")[0]) )
            else:
                if( V.size()>3):
                    if( float(line.split("	")[0])>float(lines[k-1].split("	")[0]) ):
                    #if( float(line.split("	")[0])>V.at( V.size()-1 ) ):
                        V.push_back( float(line.split("	")[0]) )
                    else:
                        break
                else:
                    V.push_back( float(line.split("	")[0]) )

            if float(line.split("	")[1])<0:
                CP.push_back( -1*float(line.split("	")[1]) )
                #IBACK.push_back( -1*float(line.split("	")[1]) )
            else:
                CP.push_back( float(line.split("	")[1]) )
                #IBACK.push_back( float(line.split("	")[1]) )

    tree.Fill()
    counter += 1

tree.Write()
file.Write()
file.Close()
# Out:
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '9', '12', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '0', '9', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '9', '15', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '6', '9', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '12', '9', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '9', '0', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '15', '9', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '15', '15', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '3', '12', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '3', '9', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '9', '3', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '9', '6', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '3', '15', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '15', '12', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '3', '3', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '6', '15', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '9', '9', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '15', '0', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '12', '15', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '3', '0', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '15', '3', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '6', '12', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '15', '6', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '3', '6', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '12', '12', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '0', '3', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '0', '15', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '6', '6', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '0', '0', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '12', '6', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '6', '3', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '12', '3', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '3', '9', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '0', '12', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '12', '0', '']
# ['FBK', 'UFSD', 'LF', 'W12', '5', '5', 'PAD', '0', '6', '']

# %%
import os
import ROOT as root
import numpy as np
from array import array
import glob

txt_files = glob.glob("/Users/icosivi/cernbox/Desktop/QC-TS_LC2_W12_IV-CV/*.txt")


lines = []

for txt in txt_files:
	#print(txt)
	header = []

	with open(txt, 'r') as f:
		lines = f.readlines()
	
	with open(txt, 'w') as f:
		for m in txt:
			if m.isdigit() or m=='A' or m=='B':
				header.append(m)
				#print(m)
		print(header)


		for number, line in enumerate(lines):
			if number == 0:
				f.write('producer structure wafer side column row \n')
			if number == 1:
				f.write('FBK 1x1 1'+' '+str(header[4])+' '+str(header[5])+' '+str(header[6])+'\n')
			if number>134: # if number>115:
				f.write(line)

# %%
import os
import ROOT as root
import numpy as np
from array import array
import glob

file = root.TFile("/Users/icosivi/cernbox/MTD/QAQC/root_files/UFSDLF_1x1_CVtree_ETL-site.root", "RECREATE")
tree = root.TTree("Tree","Tree")

event = array('i', [0])
wafer = array('i', [0])
type = array('i', [0])
side = array('i', [0])
#grt = array('i', [0])
row = array('i', [0])
column = array('i', [0])

V = root.std.vector("float")()
#IBACK = root.std.vector("float")()
CP = root.std.vector("float")()

tree.Branch("wafer", wafer, 'wafer/I')
tree.Branch("event", event, 'event/I')
tree.Branch("type", type, 'type/I')
tree.Branch("side", side, 'side/I')
#tree.Branch("grt", grt, 'grt/I')
tree.Branch("row", row, 'row/I')
tree.Branch("column", column, 'column/I')


V.reserve(1000)
#IBACK.reserve(1000)
CP.reserve(1000)
tree.Branch("V", "std::vector<float>", V)
#tree.Branch("IBACK", "std::vector<float>", IBACK)
tree.Branch("CPAD", "std::vector<float>", CP)

txt_files = glob.glob("/Users/icosivi/cernbox/Desktop/QC-TS_LC2_W12_IV-CV/*.txt")

counter = 0

for txt in txt_files:

    V.clear()
    #IBACK.clear()
    CP.clear()

    event[0] = counter

    with open(txt,"r") as t:
        #print(t)
        lines_list = t.readlines()
        header = lines_list[1]
        wafer[0] = int( header.split(" ")[2] )
        type[0] = int(1)
        print(str(header))
        if str(header.split(" ")[3])=='A':
         #print('pippo A')
         side[0] = int(0)
        elif str(header.split(" ")[3])=='B':
         #print('pippo B')
         side[0] = int(1)
        column[0] = int( header.split(" ")[4] )
        row[0] = int( header.split(" ")[5] )
        lines = lines_list[3:]

        '''
        for line in lines:
            if float(line.split("	")[1])<0:
                IBACK.push_back( -1*float(line.split("	")[1]) )
            else:
                IBACK.push_back( float(line.split(" ")[1]) )

            if(V.size()>3):
                if( -1*float(line.split("	")[0])>V.at( V.size()-1 ) ):
                    V.push_back( -1*float(line.split("	")[0]) )
                else:
                    break
            else:
                V.push_back( -1*float(line.split("	")[0]) )

        '''
        for line in lines:
            if float(line.split("	")[0])<0:
                if( V.size()>3):
                    if( -1*float(line.split("	")[0])>V.at( V.size()-1 ) ):
                        V.push_back( -1*float(line.split("	")[0]) )
                    else:
                        break
                else:
                    V.push_back( -1*float(line.split("	")[0]) )
            else:
                if( V.size()>3):
                    if( float(line.split("	")[0])>V.at( V.size()-1 ) ):
                        V.push_back( float(line.split("	")[0]) )
                    else:
                        break
                else:
                    V.push_back( float(line.split("	")[0]) )

            if float(line.split("	")[1])<0:
                CP.push_back( -1*float(line.split("	")[1]) )
                #IBACK.push_back( -1*float(line.split("	")[1]) )
            else:
                CP.push_back( float(line.split("	")[1]) )
                #IBACK.push_back( float(line.split("	")[1]) )

    tree.Fill()
    counter += 1

tree.Write()
file.Write()
file.Close()
